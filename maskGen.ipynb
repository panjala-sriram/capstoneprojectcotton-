# %%
import os
import cv2
import json
import numpy as np 

source_folder = os.path.join(os.getcwd(), "images 1")
json_path = "via_project_14Jan2021_21h7m_json.json"                     # Relative to root directory
count = 0                                           # Count of total images saved
file_bbs = {}                                       # Dictionary containing polygon coordinates for mask
MASK_WIDTH = 128									# Dimensions should match those of ground truth image
MASK_HEIGHT =128									

# Read JSON file
with open(json_path) as f:
    data = json.load(f)

# Extract X and Y coordinates if available and update dictionary
def add_to_dict(data, itr, key, count):
    try:
        x_points = data[itr]["regions"][count]["shape_attributes"]["all_points_x"]
        y_points = data[itr]["regions"][count]["shape_attributes"]["all_points_y"]
        print("hello")
    except:
        print("No BB. Skipping", key)
        return
    
    all_points = []
    for i, x in enumerate(x_points):
        all_points.append([x, y_points[i]])
    
    file_bbs[key] = all_points
for itr in data:
    file_name_json = data[itr]["filename"]
    sub_count = 0               # Contains count of masks for a single ground truth image
    
    if len(data[itr]["regions"]) > 1:
        for _ in range(len(data[itr]["regions"])):
            key = file_name_json[:-4] + "*" + str(sub_count+1)
            add_to_dict(data, itr, key, sub_count)
            sub_count += 1
    else:
        add_to_dict(data, itr, file_name_json[:-4], 0)

			
print("\nDict size: ", len(file_bbs))

for file_name in os.listdir(source_folder):
    to_save_folder = os.path.join(source_folder, file_name[:-4])
    image_folder = os.path.join(to_save_folder, "images")
    mask_folder = os.path.join(to_save_folder, "masks")
    curr_img = os.path.join(source_folder, file_name)
    
    # make folders and copy image to new location
    os.mkdir(to_save_folder)
    os.mkdir(image_folder)
    os.mkdir(mask_folder)
    os.rename(curr_img, os.path.join(image_folder, file_name))
        
# For each entry in dictionary, generate mask and save in correponding 
# folder
for itr in file_bbs:
    num_masks = itr.split("*")
    to_save_folder = os.path.join(source_folder, num_masks[0])
    mask_folder = os.path.join(to_save_folder, "masks")
    mask = np.zeros((MASK_WIDTH, MASK_HEIGHT))
    try:
        arr = np.array(file_bbs[itr])
    except:
        print("Not found:", itr)
        continue
    count += 1
    cv2.fillPoly(mask, [arr], color=(255))
    
    if len(num_masks) > 1:
    	cv2.imwrite(os.path.join(mask_folder, itr.replace("*", "_") + ".png") , mask)    
    else:
        cv2.imwrite(os.path.join(mask_folder, itr + ".png") , mask)
        
print("Images saved:", count)
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# No BB. Skipping OIP - 2020-04-18T015929.416
# No BB. Skipping OIP - 2020-04-18T015930.695
# No BB. Skipping OIP - 2020-04-18T015931.446
# No BB. Skipping OIP - 2020-04-18T015934.441
# No BB. Skipping OIP - 2020-04-18T015934.831
# No BB. Skipping OIP - 2020-04-18T015935.391
# No BB. Skipping OIP - 2020-04-18T015936.840
# No BB. Skipping OIP - 2020-04-18T015939.406
# No BB. Skipping OIP - 2020-04-18T015940.173
# No BB. Skipping OIP - 2020-04-18T015941.165
# No BB. Skipping OIP - 2020-04-18T015941.167
# No BB. Skipping OIP - 2020-04-18T015941.736
# No BB. Skipping OIP - 2020-04-18T015943.347
# No BB. Skipping OIP - 2020-04-18T015945.430
# No BB. Skipping OIP - 2020-04-18T015950.713
# No BB. Skipping OIP - 2020-04-18T015959.320
# No BB. Skipping OIP - 2020-04-18T020003.067
# No BB. Skipping OIP - 2020-04-18T020004.116
# No BB. Skipping OIP - 2020-04-18T020004.857
# No BB. Skipping OIP - 2020-04-18T020005.958
# No BB. Skipping OIP - 2020-04-18T020005.959
# No BB. Skipping OIP - 2020-04-18T020007.490
# No BB. Skipping OIP - 2020-04-18T020007.845
# No BB. Skipping OIP - 2020-04-18T020010.554
# No BB. Skipping OIP - 2020-04-18T020013.302
# No BB. Skipping OIP - 2020-04-18T020013.848
# No BB. Skipping OIP - 2020-04-18T020014.547
# No BB. Skipping OIP - 2020-04-18T020014.548
# No BB. Skipping OIP - 2020-04-18T020015.316
# No BB. Skipping OIP - 2020-04-18T020017.170
# No BB. Skipping OIP - 2020-04-18T020017.171
# No BB. Skipping OIP - 2020-04-18T020028.057
# No BB. Skipping OIP - 2020-04-18T020032.525
# No BB. Skipping OIP - 2020-04-18T020032.526
# No BB. Skipping OIP - 2020-04-18T020033.118
# No BB. Skipping OIP - 2020-04-18T020035.178
# No BB. Skipping OIP - 2020-04-18T020035.564
# No BB. Skipping OIP - 2020-04-18T020035.669
# No BB. Skipping OIP - 2020-04-18T020043.373
# No BB. Skipping OIP - 2020-04-18T020045.361
#
# Dict size:  57
# Images saved: 57

# %%
import json

with open('example1.json') as f:
    data1 = json.load(f)
    print(data1)
with open('example2.json') as f:
    data2 = json.load(f)


items1 = data1["items"]
#print(json.dumps(items1, indent=2))
items2 = data2["items"]

listitem = [items1, items2, ]
finaljson = {"items" : []}

finaljson["items"].append(items1)
finaljson["items"].append(items2)
print(json.dumps(finaljson, indent=2))

with open('merged_json.json', "w") as f:
    f.write(json.dumps(finaljson, indent=2))
# Out:
# {'download (1).jpg': {'fileref': '', 'size': 2173, 'filename': 'download (1).jpg', 'base64_img_data': '', 'file_attributes': {}, 'regions': {'0': {'shape_attributes': {'name': 'polygon', 'all_points_x': [77.36220472440945, 78.74015748031496, 75.59055118110237, 72.83464566929135, 66.73228346456693, 60.82677165354331, 60.82677165354331, 65.15748031496064, 68.50393700787401, 74.40944881889764, 78.1496062992126, 81.10236220472441, 85.23622047244095, 78.74015748031496, 76.96850393700788, 68.11023622047244, 64.96062992125985, 64.76377952755905, 71.65354330708662, 71.06299212598425, 67.91338582677166, 63.38582677165355, 59.645669291338585, 54.330708661417326, 53.93700787401575, 62.00787401574804, 62.00787401574804, 58.07086614173229, 51.968503937007874, 47.44094488188976, 42.51968503937008, 42.71653543307087, 49.01574803149607, 50, 46.85039370078741, 34.25196850393701, 30.708661417322837, 29.330708661417326, 34.645669291338585, 39.960629921259844, 40.15748031496063, 34.25196850393701, 28.740157480314963, 21.062992125984252, 16.338582677165356, 14.566929133858268, 18.897637795